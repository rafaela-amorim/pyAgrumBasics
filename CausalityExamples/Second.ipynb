# %%
# This example is from the book --- Causal Inference in Statistics: A Primer
# page 62, figure 3.6

from IPython.display import display, Math, Latex, HTML

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.causal as csl
import pyAgrum.causal.notebook as cslnb

bn = gum.fastBN("x->y<-w")

# -- conditional probabilities table
bn.cpt('w')[:] = [0.7, 0.3]

bn.cpt('x')[:] = [0.4, 0.6]

bn.cpt('y')[{'x':0, 'w':0}] = [0.2, 0.8]
bn.cpt('y')[{'x':0, 'w':1}] = [0.1, 0.9]
bn.cpt('y')[{'x':1, 'w':0}] = [0.9, 0.1]
bn.cpt('y')[{'x':1, 'w':0}] = [0.5, 0.5]


# ** making the Causal Model

d = csl.CausalModel(bn, [('z', ['x', 'w'])])

cslnb.showCausalImpact(d, 'y', 'x', values={'x':0})
cslnb.showCausalImpact(d, 'y', 'x', values={'x':1})
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="156pt" viewBox="0.00 0.00 134.00 155.60" width="134pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 151.6)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-151.6 130,-151.6 130,4 -4,4" stroke="transparent"/>
# <!-- x -->
# <g class="node" id="node1">
# <title>x</title>
# <ellipse cx="27" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-86.3">x</text>
# </g>
# <!-- y -->
# <g class="node" id="node2">
# <title>y</title>
# <ellipse cx="63" cy="-18" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">y</text>
# </g>
# <!-- x&#45;&gt;y -->
# <g class="edge" id="edge1">
# <title>x-&gt;y</title>
# <path d="M34.8202,-72.1236C39.0652,-63.6334 44.2591,-53.2456 48.9719,-43.8202" fill="none" stroke="#000000"/>
# <path d="M36.609,-73.018C40.8541,-64.5279 46.048,-54.1401 50.7607,-44.7146" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="53.024,-45.7782 54.3657,-35.2687 46.763,-42.6477 53.024,-45.7782" stroke="#000000"/>
# </g>
# <!-- w -->
# <g class="node" id="node3">
# <title>w</title>
# <ellipse cx="99" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">w</text>
# </g>
# <!-- w&#45;&gt;y -->
# <g class="edge" id="edge4">
# <title>w-&gt;y</title>
# <path d="M89.391,-73.018C85.1459,-64.5279 79.952,-54.1401 75.2393,-44.7146" fill="none" stroke="#000000"/>
# <path d="M91.1798,-72.1236C86.9348,-63.6334 81.7409,-53.2456 77.0281,-43.8202" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.237,-42.6477 71.6343,-35.2687 72.976,-45.7782 79.237,-42.6477" stroke="#000000"/>
# </g>
# <!-- z -->
# <g class="node" id="node4">
# <title>z</title>
# <ellipse cx="63" cy="-145.8" fill="#a08080" rx="1.8" ry="1.8" stroke="#000000"/>
# </g>
# <!-- z&#45;&gt;x -->
# <g class="edge" id="edge2">
# <title>z-&gt;x</title>
# <path d="M61.8022,-143.9434C58.8467,-139.3624 50.8969,-127.0402 43.3406,-115.3279" fill="none" stroke="#000000" stroke-dasharray="5,2"/>
# <polygon fill="#000000" points="46.0904,-113.134 37.7281,-106.6285 40.2083,-116.9289 46.0904,-113.134" stroke="#000000"/>
# </g>
# <!-- z&#45;&gt;w -->
# <g class="edge" id="edge3">
# <title>z-&gt;w</title>
# <path d="M64.1978,-143.9434C67.1533,-139.3624 75.1031,-127.0402 82.6594,-115.3279" fill="none" stroke="#000000" stroke-dasharray="5,2"/>
# <polygon fill="#000000" points="85.7917,-116.9289 88.2719,-106.6285 79.9096,-113.134 85.7917,-116.9289" stroke="#000000"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style="">$$\begin{equation}P( y \mid \hookrightarrow\mkern-6.5mux) = \sum_{w}{P\left(y\mid w,x\right) \cdot P\left(w\right)}\end{equation}$$</div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='2'><center>y</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><td style='color:black;background-color:#e99464;text-align:right;'>0.1700</td><td style='color:black;background-color:#94e964;text-align:right;'>0.8300</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Causal Model</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Explanation : backdoor ['w'] found.</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Impact : $P( y \mid \hookrightarrow\mkern-6.5mux=0)$</small></div></td></tr></table>
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg height="156pt" viewBox="0.00 0.00 134.00 155.60" width="134pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 151.6)">
# <title>G</title>
# <polygon fill="#ffffff" points="-4,4 -4,-151.6 130,-151.6 130,4 -4,4" stroke="transparent"/>
# <!-- x -->
# <g class="node" id="node1">
# <title>x</title>
# <ellipse cx="27" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="27" y="-86.3">x</text>
# </g>
# <!-- y -->
# <g class="node" id="node2">
# <title>y</title>
# <ellipse cx="63" cy="-18" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">y</text>
# </g>
# <!-- x&#45;&gt;y -->
# <g class="edge" id="edge1">
# <title>x-&gt;y</title>
# <path d="M34.8202,-72.1236C39.0652,-63.6334 44.2591,-53.2456 48.9719,-43.8202" fill="none" stroke="#000000"/>
# <path d="M36.609,-73.018C40.8541,-64.5279 46.048,-54.1401 50.7607,-44.7146" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="53.024,-45.7782 54.3657,-35.2687 46.763,-42.6477 53.024,-45.7782" stroke="#000000"/>
# </g>
# <!-- w -->
# <g class="node" id="node3">
# <title>w</title>
# <ellipse cx="99" cy="-90" fill="#404040" rx="27" ry="18" stroke="#000000"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">w</text>
# </g>
# <!-- w&#45;&gt;y -->
# <g class="edge" id="edge4">
# <title>w-&gt;y</title>
# <path d="M89.391,-73.018C85.1459,-64.5279 79.952,-54.1401 75.2393,-44.7146" fill="none" stroke="#000000"/>
# <path d="M91.1798,-72.1236C86.9348,-63.6334 81.7409,-53.2456 77.0281,-43.8202" fill="none" stroke="#000000"/>
# <polygon fill="#000000" points="79.237,-42.6477 71.6343,-35.2687 72.976,-45.7782 79.237,-42.6477" stroke="#000000"/>
# </g>
# <!-- z -->
# <g class="node" id="node4">
# <title>z</title>
# <ellipse cx="63" cy="-145.8" fill="#a08080" rx="1.8" ry="1.8" stroke="#000000"/>
# </g>
# <!-- z&#45;&gt;x -->
# <g class="edge" id="edge2">
# <title>z-&gt;x</title>
# <path d="M61.8022,-143.9434C58.8467,-139.3624 50.8969,-127.0402 43.3406,-115.3279" fill="none" stroke="#000000" stroke-dasharray="5,2"/>
# <polygon fill="#000000" points="46.0904,-113.134 37.7281,-106.6285 40.2083,-116.9289 46.0904,-113.134" stroke="#000000"/>
# </g>
# <!-- z&#45;&gt;w -->
# <g class="edge" id="edge3">
# <title>z-&gt;w</title>
# <path d="M64.1978,-143.9434C67.1533,-139.3624 75.1031,-127.0402 82.6594,-115.3279" fill="none" stroke="#000000" stroke-dasharray="5,2"/>
# <polygon fill="#000000" points="85.7917,-116.9289 88.2719,-106.6285 79.9096,-113.134 85.7917,-116.9289" stroke="#000000"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style="">$$\begin{equation}P( y \mid \hookrightarrow\mkern-6.5mux) = \sum_{w}{P\left(y\mid w,x\right) \cdot P\left(w\right)}\end{equation}$$</div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='2'><center>y</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><td style='color:black;background-color:#bfbe64;text-align:right;'>0.4965</td><td style='color:black;background-color:#bebf64;text-align:right;'>0.5035</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Causal Model</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Explanation : backdoor ['w'] found.</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Impact : $P( y \mid \hookrightarrow\mkern-6.5mux=1)$</small></div></td></tr></table>
